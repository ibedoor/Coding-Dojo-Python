# %% [markdown]
# <a href="https://colab.research.google.com/github/ibedoor/Coding-Dojo-Python/blob/main/Copy_of_05_Presentation_Layouts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="https://bokeh.org/">
#            <img
#                src="https://github.com/daniel-dc-cd/data_science/blob/master/daily_materials/bokeh-notebooks/tutorial/assets/bokeh-transparent.png?raw=1"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>05. Presentation and Layout</h2></div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

output_notebook()

# %% [markdown]
# In the previous chapters we started to learn how to create single plots using differnet kinds of data. But we often want to plot more than one thing. Bokeh plots can be individually embedded in HTML documents, but it's often easier to
# combine multiple plots in one of Bokeh's built-in layouts. We will learn how to do that in this chapter
#
# The cell below defines a few data variables we will use in examples.

# %%
x = list(range(11))
y0, y1, y2 = x, [10-i for i in x], [abs(i-5) for i in x]

# %% [markdown]
# # Rows and Columns
# The `bokeh.layouts` modules provides the ``row`` and ``column`` functions to arrange plot objects in vertical or horizontal layouts. Below is an example of three plots arranged in a row.

# %%
from bokeh.layouts import row

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# show the results in a row
show(row(s1, s2, s3));
# Out:
#   <div class="bk-root" id="9bd73f5e-71ef-4c51-87ff-b29b92d6dce6" data-root-id="1109"></div>

# %%
# EXERCISE: use column to arrange a few plots vertically (don't forget to import column)
from bokeh.layouts import column
show(column(s1,s2,s3));
# Out:
#   <div class="bk-root" id="43b5a729-f453-48e4-9f39-86883dfaaec4" data-root-id="1299"></div>

# %% [markdown]
# # Grid plots
#
# Bokeh also provides a `gridplot` layout in `bokeh.layouts` for arranging plots in a grid, as show in the example below.

# %%
from bokeh.layouts import gridplot

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# put all the plots in a gridplot
p = gridplot([[s1, s2], [s3, None]], toolbar_location=None)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="eed0dfde-487c-491e-9215-8b6093f46055" data-root-id="1654"></div>

# %%
# EXERCISE: create a gridplot of your own
import numpy as np
import math

x = np.arange(0, math.pi*2, 0.05)
y1= np.sin(x)
y2 = np.cos(x)

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.line(x, y1, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.line(x, y2, color="firebrick", alpha=0.5)

# put all the plots in a gridplot
p = gridplot([[s1, s2]], toolbar_location=None)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="f5da32b6-0a3c-48cd-8def-bac4393c2b0e" data-root-id="1990"></div>

# %% [markdown]
# # Next Section

# %% [markdown]
# Click on this link to go to the next notebook: [06 - Linking and Interactions](06%20-%20Linking%20and%20Interactions.ipynb).
#
# To go back to the overview, click [here](00%20-%20Introduction%20and%20Setup.ipynb).

# %% [markdown]
# ##**Level 1 Bonus**

# %%
import pandas as pd
# load in some stock data from gumdropsteve/datasets
apple = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/stocks/AAPL.csv')
tsla = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/stocks/TSLA.csv')

# %% [markdown]
# Show the tial for Apple Dataset

# %%
apple.tail()
# Out:
#             Date        Open        High  ...       Close   Adj Close     Volume
# 2512  2020-11-10  115.550003  117.589996  ...  115.970001  115.970001  138023400
# 2513  2020-11-11  117.190002  119.629997  ...  119.489998  119.489998  112295000
# 2514  2020-11-12  119.620003  120.529999  ...  119.209999  119.209999  103162300
# 2515  2020-11-13  119.440002  119.669998  ...  119.260002  119.260002   81581900
# 2516  2020-11-16  118.919998  120.989998  ...  120.300003  120.300003   91183000
#
# [5 rows x 7 columns]

# %% [markdown]
# Show the tial for Tsla Dataset

# %%
tsla.tail()
# Out:
#               ds  opening_price        high  ...       close   adj_close    volume
# 2512  2020-11-10     420.089996  420.089996  ...  410.359985  410.359985  30284200
# 2513  2020-11-11     416.450012  418.700012  ...  417.130005  417.130005  17357700
# 2514  2020-11-12     415.049988  423.000000  ...  411.760010  411.760010  19855100
# 2515  2020-11-13     410.850006  412.529999  ...  408.500000  408.500000  19771100
# 2516  2020-11-16     408.929993  412.450012  ...  408.089996  408.089996  26838600
#
# [5 rows x 7 columns]

# %% [markdown]
# Determine x and y for Apple

# %%
apple_x = [i for i in range(500)]
apple_y = [i for i in apple['Adj Close'].sample(500)]

# %% [markdown]
# Determine x and y for Tsla

# %%
tsla_x = [i for i in range(500)]
tsla_y = [i for i in tsla['adj_close'].sample(500)]

# %% [markdown]
# **Visualization**

# %%
from bokeh.plotting import figure,output_file, show
p = figure(title="Compare Apple and Tsla Stock Data", x_axis_label='x', y_axis_label='y', plot_width=900, plot_height=400)
p.line(apple_x, apple_y, line_width=2, color='red')
p.line(tsla_x, tsla_y, line_width=2, color='blue')

show(p);
# Out:
#   <div class="bk-root" id="15d0190f-949f-4c16-b217-bcdb2163e41d" data-root-id="3977"></div>

# %% [markdown]
# #**Level 2 Bonus**

# %% [markdown]
# Import Dataset

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %% [markdown]
# Show First Rows

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# **Visualization**

# %% [markdown]
# Range of Fare Amount

# %%
x = [i for i in range(50)]
y = [i for i in df['fare'].tail(50)]

# %%
p = figure(plot_width=500, plot_height=400, x_axis_label='x', y_axis_label='Fare') 
p.line(x, y, alpha=0.5, color='red')
show(p)
# Out:
#   <div class="bk-root" id="6881d64c-3401-4b94-a9bc-a303f7f582df" data-root-id="13136"></div>

# %% [markdown]
# Numbers of People Who Survived and Who Died

# %%
from bokeh.plotting import figure
count_survived = df.survived.value_counts()
index_y = ['Died','Survived']
p = figure(x_range = index_y, plot_height = 250, plot_width=200, toolbar_location = None, tools = '')
p.vbar(x=index_y, top = count_survived, width=0.9)
p.xgrid.grid_line_color = None
p.y_range.start = 0
show(p)
# Out:
#   <div class="bk-root" id="a00f8cd3-0817-49d0-be7c-4fc02178b6b3" data-root-id="22276"></div>

# %%
x = [i for i in range(100)]
y = [i for i in df['age'].sample(100)]

# %%
p = figure(plot_width=600, plot_height=400, x_axis_label='x', y_axis_label='Age') 
p.line(x, y, alpha=0.5, color='red')
show(p)
# Out:
#   <div class="bk-root" id="f4ae6f23-9f41-49a8-9bd1-211dd71e1c0b" data-root-id="24125"></div>

# %% [markdown]
# #**Level 3 Bonus**

# %%
import pandas as pd
airlines = pd.read_parquet('https://github.com/gumdropsteve/datasets/raw/master/airlines.parquet')
airlines
# Out:
#          ArrDelayBinary  t_Year  t_Month  ...   Dest  Distance  Diverted
# 0                     0  1991.0      8.0  ...  244.0     110.0       0.0
# 1                     0  1990.0     11.0  ...   11.0     595.0       0.0
# 2                     0  1991.0      1.0  ...  175.0     412.0       0.0
# 3                     0  1991.0      6.0  ...   11.0     545.0       0.0
# 4                     0  1988.0     10.0  ...  171.0     866.0       0.0
# ...                 ...     ...      ...  ...    ...       ...       ...
# 3999995               0  1987.0     10.0  ...  150.0     332.0       0.0
# 3999996               0  1990.0      7.0  ...   22.0     321.0       0.0
# 3999997               0  1987.0     11.0  ...    8.0     108.0       0.0
# 3999998               0  1991.0      8.0  ...  149.0     395.0       0.0
# 3999999               0  1990.0      7.0  ...   96.0     288.0       0.0
#
# [4000000 rows x 14 columns]
